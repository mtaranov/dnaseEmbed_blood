# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
all_chrs=[str(i+1) for i in range(22)]+['X']

# %%
for i in all_chrs:
    first2comp = np.load('/users/mtaranov/dnaseEmbed_blood/data/tsne_chr'+i+'.npy')
    print first2comp.shape
    plt.scatter(first2comp[:,0], first2comp[:,1])
    plt.title('TSNE - chr'+i)
    plt.show()
# Out:
# (10033, 2)
# (7644, 2)
# (6037, 2)
# (3835, 2)
# (5020, 2)
# (6215, 2)
# (4732, 2)
# (4164, 2)
# (4223, 2)
# (4793, 2)
# (5372, 2)
# (5241, 2)
# (2124, 2)
# (3449, 2)
# (3323, 2)
# (4235, 2)
# (5819, 2)
# (2024, 2)
# (5661, 2)
# (3101, 2)
# (1194, 2)
# (2519, 2)
# (2540, 2)
