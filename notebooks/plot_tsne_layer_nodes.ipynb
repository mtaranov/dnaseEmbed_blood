# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
all_chrs=[str(i+1) for i in range(22)]+['X']

# %%
for i in all_chrs:
    first2comp = np.load('/users/mtaranov/dnaseEmbed_blood/data/tsne_layer_nodes_chr'+i+'.npy')
    print first2comp.shape
    plt.scatter(first2comp[:,0], first2comp[:,1])
    plt.title('TSNE - chr'+i)
    plt.show()
# Out:
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
# (1000, 2)
